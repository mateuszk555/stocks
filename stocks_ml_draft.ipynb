# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import math

from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.callbacks import CSVLogger

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn.cross_validation import  train_test_split
from sklearn.cross_validation import cross_val_score

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import scorer
from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.
# C:\Users\mateu\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
sharpes = pd.DataFrame(columns=['STOCK','ANN','SVM','KNN','LR','acc_ANN_train','acc_ANN_test','acc_SVM_train','acc_SVM_test','acc_KNN_train','acc_KNN_test','acc_LR_train','acc_LR_test'])

# %%
stock_name = 'GE'
df = pd.read_csv('all_stocks_5yr.csv')
df = df.drop(['volume'], axis=1)
stock_names = df.Name.unique()

# %%
def extract_stock(stock_name):
    df_stock = df.loc[df['Name'] == stock_name]
    df_stock = df_stock.drop(['Name'], axis=1)
    df_stock = df_stock.dropna()
    df_stock['date'] = pd.to_datetime(df_stock['date'])
    df_stock['close'] = pd.to_numeric(df_stock['close'], downcast='float')
    df_stock.set_index('date',inplace=True)
    df_stock.sort_index(inplace=True)
    
    return df_stock

# %%
############################################################################################
################################### 0. ALL SCRIPTS START ###################################
############################################################################################

# %%
### ANN

#get stock
df_stock = extract_stock(stock_name)

#prepare variables
df_stock['H-L'] = df_stock['high'] - df_stock['low']
df_stock['O-C'] = df_stock['close'] - df_stock['open']
df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
df_stock['Std_dev']= df_stock['close'].rolling(5).std()

#prepare predicted
df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
#remove na after shift
df_stock = df_stock.dropna()
    
#define X
X = df_stock.iloc[:, 4:-1]
    
#define y
y = df_stock.iloc[:, -1]
    
#define split
split_percentage = 0.8
split = int(len(df_stock)*split_percentage)
    
#prepare train and test sets
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
#define scaler
sc = StandardScaler()
    
#scale-replace X_train and X_test
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
    
#define model
classifier = Sequential()
classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', input_dim = X.shape[1]))
classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])
    
#teach model
csv_logger = CSVLogger('log.csv', append=False, separator=',')
history = classifier.fit(X_train, y_train, batch_size = 10, epochs = 150, verbose = 1, callbacks=[csv_logger], validation_data=(X_test, y_test))

y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
    
df_stock['y_pred'] = np.NaN
df_stock.iloc[(len(df_stock) - len(y_pred)):,-1:] = y_pred
df_stock = df_stock.dropna()

#create metric
score = classifier.evaluate(X_test, y_test, verbose=1)

accuracy_train_ANN = history.history['acc'][-1]
accuracy_test_ANN = score[1]

#calculate returns
df_stock['Tomorrows Returns'] = 0.
df_stock['Tomorrows Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
df_stock['Tomorrows Returns'] = df_stock['Tomorrows Returns'].shift(-1)

df_stock['Strategy Returns'] = 0.
df_stock['Strategy Returns'] = np.where(df_stock['y_pred'] == True, df_stock['Tomorrows Returns'], - df_stock['Tomorrows Returns'])

df_stock['Cumulative Market Returns'] = np.cumsum(df_stock['Tomorrows Returns'])
df_stock['Cumulative Strategy Returns'] = np.cumsum(df_stock['Strategy Returns'])

Cumulative_Strategy_Returns = df_stock['Cumulative Strategy Returns']*100
Cumulative_Market_Returns = df_stock['Cumulative Market Returns']

Cumulative_ANN_Returns = Cumulative_Strategy_Returns

#calculate sharpe ratio
Std = Cumulative_Strategy_Returns.std()
Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
Sharpe_ANN = Sharpe.mean()

# %%
### ANN2

#get stock
df_stock = extract_stock('GE')

#prepare variables
df_stock['H-L'] = df_stock['high'] - df_stock['low']
df_stock['O-C'] = df_stock['close'] - df_stock['open']
df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
df_stock['Std_dev']= df_stock['close'].rolling(5).std()

#prepare predicted
df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
#remove na after shift
df_stock = df_stock.dropna()
    
#define X
X = df_stock.iloc[:, 4:-1]
    
#define y
y = df_stock.iloc[:, -1]
    
#define split
split_percentage = 0.8
split = int(len(df_stock)*split_percentage)
    
#prepare train and test sets
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
#define scaler
sc = StandardScaler()
scaler = MinMaxScaler(feature_range=(0,1))
    
#scale-replace X_train and X_test
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
len(X_train)
plt.figure(figsize=(15,8))
plt.plot(X_train)
# Out:
# [<matplotlib.lines.Line2D at 0x1a4b519cbe0>,
#  <matplotlib.lines.Line2D at 0x1a4b519cdd8>,
#  <matplotlib.lines.Line2D at 0x1a4b519cf28>,
#  <matplotlib.lines.Line2D at 0x1a4b570b0b8>,
#  <matplotlib.lines.Line2D at 0x1a4b570b208>,
#  <matplotlib.lines.Line2D at 0x1a4b570b358>]

# %%
  
#define model
classifier = Sequential()
classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', input_dim = X.shape[1]))
classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])
    
#teach model
csv_logger = CSVLogger('log.csv', append=False, separator=',')
history = classifier.fit(X_train, y_train, batch_size = 10, epochs = 150, verbose = 1, callbacks=[csv_logger], validation_data=(X_test, y_test))
# Out:
# Train on 983 samples, validate on 246 samples
# Epoch 1/150
# 983/983 [==============================] - 1s 988us/step - loss: 0.2500 - acc: 0.5127 - val_loss: 0.2564 - val_acc: 0.4472
# Epoch 2/150
# 983/983 [==============================] - 0s 104us/step - loss: 0.2492 - acc: 0.5209 - val_loss: 0.2617 - val_acc: 0.4309
# Epoch 3/150
# 983/983 [==============================] - 0s 106us/step - loss: 0.2487 - acc: 0.5188 - val_loss: 0.2692 - val_acc: 0.4350
# Epoch 4/150
# 983/983 [==============================] - 0s 106us/step - loss: 0.2481 - acc: 0.5239 - val_loss: 0.2712 - val_acc: 0.4350
# Epoch 5/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.2477 - acc: 0.5249 - val_loss: 0.2697 - val_acc: 0.4309
# Epoch 6/150
# 983/983 [==============================] - 0s 99us/step - loss: 0.2473 - acc: 0.5341 - val_loss: 0.2717 - val_acc: 0.4187
# Epoch 7/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.2473 - acc: 0.5290 - val_loss: 0.2735 - val_acc: 0.4431
# Epoch 8/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2469 - acc: 0.5351 - val_loss: 0.2624 - val_acc: 0.4512
# Epoch 9/150
# 983/983 [==============================] - 0s 101us/step - loss: 0.2473 - acc: 0.5412 - val_loss: 0.2741 - val_acc: 0.4472
# Epoch 10/150
# 983/983 [==============================] - 0s 104us/step - loss: 0.2465 - acc: 0.5381 - val_loss: 0.2799 - val_acc: 0.4309
# Epoch 11/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.2466 - acc: 0.5331 - val_loss: 0.2667 - val_acc: 0.4350
# Epoch 12/150
# 983/983 [==============================] - 0s 108us/step - loss: 0.2458 - acc: 0.5392 - val_loss: 0.2754 - val_acc: 0.4350
# Epoch 13/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.2460 - acc: 0.5412 - val_loss: 0.2820 - val_acc: 0.4350
# Epoch 14/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.2455 - acc: 0.5351 - val_loss: 0.2703 - val_acc: 0.4431
# Epoch 15/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2461 - acc: 0.5493 - val_loss: 0.2742 - val_acc: 0.4350
# Epoch 16/150
# 983/983 [==============================] - 0s 101us/step - loss: 0.2455 - acc: 0.5381 - val_loss: 0.2798 - val_acc: 0.4431
# Epoch 17/150
# 983/983 [==============================] - 0s 134us/step - loss: 0.2451 - acc: 0.5422 - val_loss: 0.2787 - val_acc: 0.4431
# Epoch 18/150
# 983/983 [==============================] - 0s 105us/step - loss: 0.2452 - acc: 0.5463 - val_loss: 0.2792 - val_acc: 0.4431
# Epoch 19/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.2445 - acc: 0.5534 - val_loss: 0.2707 - val_acc: 0.4512
# Epoch 20/150
# 983/983 [==============================] - 0s 107us/step - loss: 0.2446 - acc: 0.5483 - val_loss: 0.2712 - val_acc: 0.4390
# Epoch 21/150
# 983/983 [==============================] - 0s 109us/step - loss: 0.2440 - acc: 0.5554 - val_loss: 0.2730 - val_acc: 0.4390
# Epoch 22/150
# 983/983 [==============================] - 0s 112us/step - loss: 0.2434 - acc: 0.5534 - val_loss: 0.2738 - val_acc: 0.4390
# Epoch 23/150
# 983/983 [==============================] - 0s 110us/step - loss: 0.2433 - acc: 0.5544 - val_loss: 0.2809 - val_acc: 0.4390
# Epoch 24/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.2437 - acc: 0.5504 - val_loss: 0.2780 - val_acc: 0.4431
# Epoch 25/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.2440 - acc: 0.5422 - val_loss: 0.2758 - val_acc: 0.4350
# Epoch 26/150
# 983/983 [==============================] - 0s 108us/step - loss: 0.2429 - acc: 0.5585 - val_loss: 0.2936 - val_acc: 0.4553
# Epoch 27/150
# 983/983 [==============================] - 0s 99us/step - loss: 0.2424 - acc: 0.5666 - val_loss: 0.2836 - val_acc: 0.4431
# Epoch 28/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2429 - acc: 0.5605 - val_loss: 0.2684 - val_acc: 0.4837
# Epoch 29/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2415 - acc: 0.5707 - val_loss: 0.2824 - val_acc: 0.4593
# Epoch 30/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2415 - acc: 0.5707 - val_loss: 0.2803 - val_acc: 0.4472
# Epoch 31/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2417 - acc: 0.5646 - val_loss: 0.2798 - val_acc: 0.4472
# Epoch 32/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.2406 - acc: 0.5687 - val_loss: 0.2784 - val_acc: 0.4593
# Epoch 33/150
# 983/983 [==============================] - 0s 101us/step - loss: 0.2401 - acc: 0.5819 - val_loss: 0.2854 - val_acc: 0.4553
# Epoch 34/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2398 - acc: 0.5748 - val_loss: 0.2844 - val_acc: 0.4593
# Epoch 35/150
# 983/983 [==============================] - 0s 103us/step - loss: 0.2397 - acc: 0.5778 - val_loss: 0.2717 - val_acc: 0.4715
# Epoch 36/150
# 983/983 [==============================] - 0s 91us/step - loss: 0.2396 - acc: 0.5799 - val_loss: 0.2756 - val_acc: 0.4593
# Epoch 37/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.2391 - acc: 0.5788 - val_loss: 0.3007 - val_acc: 0.4431
# Epoch 38/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.2386 - acc: 0.5717 - val_loss: 0.2767 - val_acc: 0.4472
# Epoch 39/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.2375 - acc: 0.5707 - val_loss: 0.2799 - val_acc: 0.4350
# Epoch 40/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.2370 - acc: 0.5727 - val_loss: 0.2909 - val_acc: 0.4553
# Epoch 41/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.2359 - acc: 0.5900 - val_loss: 0.2721 - val_acc: 0.4593
# Epoch 42/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2358 - acc: 0.5931 - val_loss: 0.2925 - val_acc: 0.4472
# Epoch 43/150
# 983/983 [==============================] - 0s 106us/step - loss: 0.2353 - acc: 0.5931 - val_loss: 0.2870 - val_acc: 0.4634
# Epoch 44/150
# 983/983 [==============================] - 0s 105us/step - loss: 0.2338 - acc: 0.5870 - val_loss: 0.2881 - val_acc: 0.4431
# Epoch 45/150
# 983/983 [==============================] - 0s 118us/step - loss: 0.2333 - acc: 0.5931 - val_loss: 0.2873 - val_acc: 0.4634
# Epoch 46/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.2329 - acc: 0.6002 - val_loss: 0.2989 - val_acc: 0.4472
# Epoch 47/150
# 983/983 [==============================] - 0s 99us/step - loss: 0.2325 - acc: 0.5982 - val_loss: 0.2895 - val_acc: 0.4553
# Epoch 48/150
# 983/983 [==============================] - 0s 104us/step - loss: 0.2329 - acc: 0.6033 - val_loss: 0.2861 - val_acc: 0.4553
# Epoch 49/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2315 - acc: 0.5941 - val_loss: 0.3005 - val_acc: 0.4512
# Epoch 50/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2309 - acc: 0.6022 - val_loss: 0.3007 - val_acc: 0.4512
# Epoch 51/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.2310 - acc: 0.5992 - val_loss: 0.3221 - val_acc: 0.4472
# Epoch 52/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.2292 - acc: 0.5972 - val_loss: 0.2966 - val_acc: 0.4309
# Epoch 53/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.2295 - acc: 0.6043 - val_loss: 0.2998 - val_acc: 0.4390
# Epoch 54/150
# 983/983 [==============================] - 0s 102us/step - loss: 0.2275 - acc: 0.6124 - val_loss: 0.3250 - val_acc: 0.4350
# Epoch 55/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2274 - acc: 0.6063 - val_loss: 0.3067 - val_acc: 0.4309
# Epoch 56/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.2270 - acc: 0.6134 - val_loss: 0.3217 - val_acc: 0.4309
# Epoch 57/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.2253 - acc: 0.6134 - val_loss: 0.3020 - val_acc: 0.4350
# Epoch 58/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2261 - acc: 0.6185 - val_loss: 0.2987 - val_acc: 0.4512
# Epoch 59/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2240 - acc: 0.6277 - val_loss: 0.3240 - val_acc: 0.4593
# Epoch 60/150
# 983/983 [==============================] - 0s 102us/step - loss: 0.2241 - acc: 0.6256 - val_loss: 0.3192 - val_acc: 0.4309
# Epoch 61/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2230 - acc: 0.6368 - val_loss: 0.3341 - val_acc: 0.4309
# Epoch 62/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.2226 - acc: 0.6185 - val_loss: 0.3283 - val_acc: 0.4553
# Epoch 63/150
# 983/983 [==============================] - 0s 90us/step - loss: 0.2223 - acc: 0.6205 - val_loss: 0.3351 - val_acc: 0.4431
# Epoch 64/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2223 - acc: 0.6226 - val_loss: 0.3074 - val_acc: 0.4715
# Epoch 65/150
# 983/983 [==============================] - 0s 102us/step - loss: 0.2203 - acc: 0.6185 - val_loss: 0.3144 - val_acc: 0.4634
# Epoch 66/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.2215 - acc: 0.6358 - val_loss: 0.3140 - val_acc: 0.4675
# Epoch 67/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.2186 - acc: 0.6439 - val_loss: 0.3159 - val_acc: 0.4593
# Epoch 68/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2176 - acc: 0.6358 - val_loss: 0.3345 - val_acc: 0.4512
# Epoch 69/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.2187 - acc: 0.6429 - val_loss: 0.3357 - val_acc: 0.4309
# Epoch 70/150
# 983/983 [==============================] - 0s 103us/step - loss: 0.2162 - acc: 0.6450 - val_loss: 0.3191 - val_acc: 0.4675
# Epoch 71/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2182 - acc: 0.6378 - val_loss: 0.3238 - val_acc: 0.4431
# Epoch 72/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2145 - acc: 0.6480 - val_loss: 0.3427 - val_acc: 0.4593
# Epoch 73/150
# 983/983 [==============================] - 0s 89us/step - loss: 0.2158 - acc: 0.6429 - val_loss: 0.3194 - val_acc: 0.4553
# Epoch 74/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.2134 - acc: 0.6429 - val_loss: 0.3445 - val_acc: 0.4756
# Epoch 75/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2136 - acc: 0.6450 - val_loss: 0.2987 - val_acc: 0.4634
# Epoch 76/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2113 - acc: 0.6643 - val_loss: 0.3217 - val_acc: 0.4675
# Epoch 77/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.2112 - acc: 0.6684 - val_loss: 0.3189 - val_acc: 0.4593
# Epoch 78/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2118 - acc: 0.6531 - val_loss: 0.3325 - val_acc: 0.4756
# Epoch 79/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.2098 - acc: 0.6490 - val_loss: 0.3205 - val_acc: 0.4593
# Epoch 80/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.2086 - acc: 0.6694 - val_loss: 0.3430 - val_acc: 0.4593
# Epoch 81/150
# 983/983 [==============================] - 0s 99us/step - loss: 0.2073 - acc: 0.6857 - val_loss: 0.3382 - val_acc: 0.4675
# Epoch 82/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2058 - acc: 0.6826 - val_loss: 0.3401 - val_acc: 0.4675
# Epoch 83/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2072 - acc: 0.6745 - val_loss: 0.3509 - val_acc: 0.4715
# Epoch 84/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2052 - acc: 0.6704 - val_loss: 0.3324 - val_acc: 0.4756
# Epoch 85/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2024 - acc: 0.6857 - val_loss: 0.3460 - val_acc: 0.4797
# Epoch 86/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.2047 - acc: 0.6704 - val_loss: 0.3619 - val_acc: 0.4837
# Epoch 87/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.2025 - acc: 0.6907 - val_loss: 0.3348 - val_acc: 0.4878
# Epoch 88/150
# 983/983 [==============================] - 0s 102us/step - loss: 0.2028 - acc: 0.6826 - val_loss: 0.3364 - val_acc: 0.4715
# Epoch 89/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.2024 - acc: 0.6877 - val_loss: 0.3348 - val_acc: 0.4756
# Epoch 90/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.2005 - acc: 0.6775 - val_loss: 0.3630 - val_acc: 0.4634
# Epoch 91/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.2003 - acc: 0.6877 - val_loss: 0.3618 - val_acc: 0.4756
# Epoch 92/150
# 983/983 [==============================] - 0s 107us/step - loss: 0.2001 - acc: 0.6745 - val_loss: 0.3330 - val_acc: 0.4715
# Epoch 93/150
# 983/983 [==============================] - 0s 108us/step - loss: 0.1986 - acc: 0.6958 - val_loss: 0.3562 - val_acc: 0.4675
# Epoch 94/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.1979 - acc: 0.6846 - val_loss: 0.3476 - val_acc: 0.4634
# Epoch 95/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.1964 - acc: 0.6877 - val_loss: 0.3121 - val_acc: 0.4634
# Epoch 96/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.1967 - acc: 0.7040 - val_loss: 0.3497 - val_acc: 0.4756
# Epoch 97/150
# 983/983 [==============================] - 0s 111us/step - loss: 0.1953 - acc: 0.6887 - val_loss: 0.3707 - val_acc: 0.4593
# Epoch 98/150
# 983/983 [==============================] - 0s 106us/step - loss: 0.1935 - acc: 0.6897 - val_loss: 0.3553 - val_acc: 0.4593
# Epoch 99/150
# 983/983 [==============================] - 0s 107us/step - loss: 0.1942 - acc: 0.6979 - val_loss: 0.3578 - val_acc: 0.4593
# Epoch 100/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.1912 - acc: 0.7040 - val_loss: 0.3473 - val_acc: 0.4553
# Epoch 101/150
# 983/983 [==============================] - 0s 102us/step - loss: 0.1908 - acc: 0.6999 - val_loss: 0.3563 - val_acc: 0.4634
# Epoch 102/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.1900 - acc: 0.7070 - val_loss: 0.3466 - val_acc: 0.4593
# Epoch 103/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.1907 - acc: 0.6989 - val_loss: 0.3675 - val_acc: 0.4715
# Epoch 104/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.1887 - acc: 0.7070 - val_loss: 0.3788 - val_acc: 0.4675
# Epoch 105/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.1875 - acc: 0.7223 - val_loss: 0.3608 - val_acc: 0.4797
# Epoch 106/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.1857 - acc: 0.7202 - val_loss: 0.3493 - val_acc: 0.4675
# Epoch 107/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.1859 - acc: 0.7172 - val_loss: 0.3767 - val_acc: 0.4756
# Epoch 108/150
# 983/983 [==============================] - 0s 97us/step - loss: 0.1840 - acc: 0.7162 - val_loss: 0.3741 - val_acc: 0.4593
# Epoch 109/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.1846 - acc: 0.7192 - val_loss: 0.3668 - val_acc: 0.4675
# Epoch 110/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.1830 - acc: 0.7243 - val_loss: 0.3619 - val_acc: 0.4756
# Epoch 111/150
# 983/983 [==============================] - 0s 100us/step - loss: 0.1827 - acc: 0.7182 - val_loss: 0.3619 - val_acc: 0.4675
# Epoch 112/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.1818 - acc: 0.7223 - val_loss: 0.3685 - val_acc: 0.4390
# Epoch 113/150
# 983/983 [==============================] - 0s 90us/step - loss: 0.1785 - acc: 0.7355 - val_loss: 0.3893 - val_acc: 0.4512
# Epoch 114/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.1794 - acc: 0.7325 - val_loss: 0.3592 - val_acc: 0.4350
# Epoch 115/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.1790 - acc: 0.7386 - val_loss: 0.3862 - val_acc: 0.4634
# Epoch 116/150
# 983/983 [==============================] - 0s 90us/step - loss: 0.1769 - acc: 0.7345 - val_loss: 0.3694 - val_acc: 0.4756
# Epoch 117/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.1798 - acc: 0.7263 - val_loss: 0.3810 - val_acc: 0.4512
# Epoch 118/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.1757 - acc: 0.7294 - val_loss: 0.3732 - val_acc: 0.4472
# Epoch 119/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.1753 - acc: 0.7406 - val_loss: 0.3806 - val_acc: 0.4634
# Epoch 120/150
# 983/983 [==============================] - 0s 95us/step - loss: 0.1758 - acc: 0.7396 - val_loss: 0.3552 - val_acc: 0.4675
# Epoch 121/150
# 983/983 [==============================] - 0s 88us/step - loss: 0.1724 - acc: 0.7436 - val_loss: 0.3928 - val_acc: 0.4309
# Epoch 122/150
# 983/983 [==============================] - 0s 86us/step - loss: 0.1731 - acc: 0.7406 - val_loss: 0.3862 - val_acc: 0.4756
# Epoch 123/150
# 983/983 [==============================] - 0s 90us/step - loss: 0.1727 - acc: 0.7426 - val_loss: 0.3853 - val_acc: 0.4553
# Epoch 124/150
# 983/983 [==============================] - 0s 89us/step - loss: 0.1703 - acc: 0.7609 - val_loss: 0.3951 - val_acc: 0.4512
# Epoch 125/150
# 983/983 [==============================] - 0s 103us/step - loss: 0.1697 - acc: 0.7508 - val_loss: 0.3858 - val_acc: 0.4593
# Epoch 126/150
# 983/983 [==============================] - 0s 98us/step - loss: 0.1695 - acc: 0.7558 - val_loss: 0.3955 - val_acc: 0.4553
# Epoch 127/150
# 983/983 [==============================] - 0s 96us/step - loss: 0.1691 - acc: 0.7477 - val_loss: 0.3903 - val_acc: 0.4553
# Epoch 128/150
# 983/983 [==============================] - 0s 105us/step - loss: 0.1665 - acc: 0.7538 - val_loss: 0.4127 - val_acc: 0.4512
# Epoch 129/150
# 983/983 [==============================] - 0s 88us/step - loss: 0.1728 - acc: 0.7314 - val_loss: 0.3955 - val_acc: 0.4593
# Epoch 130/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.1676 - acc: 0.7467 - val_loss: 0.3979 - val_acc: 0.4390
# Epoch 131/150
# 983/983 [==============================] - 0s 83us/step - loss: 0.1672 - acc: 0.7518 - val_loss: 0.3954 - val_acc: 0.4472
# Epoch 132/150
# 983/983 [==============================] - 0s 89us/step - loss: 0.1661 - acc: 0.7467 - val_loss: 0.3904 - val_acc: 0.4431
# Epoch 133/150
# 983/983 [==============================] - 0s 90us/step - loss: 0.1640 - acc: 0.7497 - val_loss: 0.3871 - val_acc: 0.4512
# Epoch 134/150
# 983/983 [==============================] - 0s 89us/step - loss: 0.1637 - acc: 0.7518 - val_loss: 0.3858 - val_acc: 0.4553
# Epoch 135/150
# 983/983 [==============================] - 0s 89us/step - loss: 0.1654 - acc: 0.7528 - val_loss: 0.3888 - val_acc: 0.4634
# Epoch 136/150
# 983/983 [==============================] - 0s 94us/step - loss: 0.1621 - acc: 0.7538 - val_loss: 0.3994 - val_acc: 0.4512
# Epoch 137/150
# 983/983 [==============================] - 0s 90us/step - loss: 0.1617 - acc: 0.7681 - val_loss: 0.3936 - val_acc: 0.4472
# Epoch 138/150
# 983/983 [==============================] - 0s 93us/step - loss: 0.1593 - acc: 0.7620 - val_loss: 0.4118 - val_acc: 0.4390
# Epoch 139/150
# 983/983 [==============================] - 0s 87us/step - loss: 0.1610 - acc: 0.7609 - val_loss: 0.4164 - val_acc: 0.4512
# Epoch 140/150
# 983/983 [==============================] - 0s 84us/step - loss: 0.1602 - acc: 0.7630 - val_loss: 0.3944 - val_acc: 0.4675
# Epoch 141/150
# 983/983 [==============================] - 0s 86us/step - loss: 0.1585 - acc: 0.7752 - val_loss: 0.4203 - val_acc: 0.4350
# Epoch 142/150
# 983/983 [==============================] - 0s 92us/step - loss: 0.1614 - acc: 0.7436 - val_loss: 0.4281 - val_acc: 0.4268
# Epoch 143/150
# 983/983 [==============================] - 0s 86us/step - loss: 0.1594 - acc: 0.7609 - val_loss: 0.4101 - val_acc: 0.4309
# Epoch 144/150
# 983/983 [==============================] - 0s 89us/step - loss: 0.1560 - acc: 0.7833 - val_loss: 0.4154 - val_acc: 0.4553
# Epoch 145/150
# 983/983 [==============================] - 0s 99us/step - loss: 0.1541 - acc: 0.7691 - val_loss: 0.3970 - val_acc: 0.4512
# Epoch 146/150
# 983/983 [==============================] - 0s 90us/step - loss: 0.1558 - acc: 0.7650 - val_loss: 0.4162 - val_acc: 0.4512
# Epoch 147/150
# 983/983 [==============================] - 0s 84us/step - loss: 0.1526 - acc: 0.7803 - val_loss: 0.4164 - val_acc: 0.4512
# Epoch 148/150
# 983/983 [==============================] - 0s 86us/step - loss: 0.1546 - acc: 0.7660 - val_loss: 0.4077 - val_acc: 0.4512
# Epoch 149/150
# 983/983 [==============================] - 0s 86us/step - loss: 0.1529 - acc: 0.7731 - val_loss: 0.4202 - val_acc: 0.4472
# Epoch 150/150
# 983/983 [==============================] - 0s 88us/step - loss: 0.1512 - acc: 0.7925 - val_loss: 0.4058 - val_acc: 0.4593

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
    
df_stock['y_pred'] = np.NaN
df_stock.iloc[(len(df_stock) - len(y_pred)):,-1:] = y_pred
df_stock = df_stock.dropna()

# %%
#create metric
score = classifier.evaluate(X_test, y_test, verbose=1)

accuracy_train_ANN = history.history['acc'][-1]
accuracy_test_ANN = score[1]
# Out:
# 246/246 [==============================] - 0s 24us/step

# %%
#calculate returns
df_stock['Tomorrows Returns'] = 0.
df_stock['Tomorrows Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
df_stock['Tomorrows Returns'] = df_stock['Tomorrows Returns'].shift(-1)

# %%
df_stock['Strategy Returns'] = 0.
df_stock['Strategy Returns'] = np.where(df_stock['y_pred'] == True, df_stock['Tomorrows Returns'], - df_stock['Tomorrows Returns'])

# %%
df_stock['Cumulative Market Returns'] = np.cumsum(df_stock['Tomorrows Returns'])
df_stock['Cumulative Strategy Returns'] = np.cumsum(df_stock['Strategy Returns'])

# %%
Cumulative_Strategy_Returns = df_stock['Cumulative Strategy Returns']*100
Cumulative_Market_Returns = df_stock['Cumulative Market Returns']*100

# %%
#calculate sharpe ratio
Std = Cumulative_Strategy_Returns.std()
Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
Sharpe_ANN = Sharpe.mean()

# %%
df_stock['Tomorrows Returns'] = 0.
df_stock['Tomorrows Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
df_stock['Tomorrows Returns'] = df_stock['Tomorrows Returns'].shift(-1)

df_stock['Strategy Returns'] = 0.
df_stock['Strategy Returns'] = np.where(df_stock['y_pred'] == True, df_stock['Tomorrows Returns'], - df_stock['Tomorrows Returns'])

df_stock['Cumulative Market Returns'] = np.cumsum(df_stock['Tomorrows Returns'])
df_stock['Cumulative Strategy Returns'] = np.cumsum(df_stock['Strategy Returns'])

Cumulative_Strategy_Returns = df_stock['Cumulative Strategy Returns']*100
Cumulative_Market_Returns = df_stock['Cumulative Market Returns']*100

#calculate sharpe ratio
Std = Cumulative_Strategy_Returns.std()
Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
Sharpe_ANN = Sharpe.mean()

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Returns')

#plt.plot(Cumulative_KNN_Returns, color='m', label='KNN Returns')
#plt.plot(Cumulative_LR_Returns, color='c', label='LR Returns')
plt.grid()
plt.legend()
plt.show()

# %%
Sharpe_ANN
# Out:
# 3.3127737045288086

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Returns')

#plt.plot(Cumulative_KNN_Returns, color='m', label='KNN Returns')
#plt.plot(Cumulative_LR_Returns, color='c', label='LR Returns')
plt.grid()
plt.legend()
plt.show()

# %%
### SVM

#get stock
df_stock = extract_stock(stock_name)
    
#prepare variables
df_stock['H-L'] = df_stock['high'] - df_stock['low']
df_stock['O-C'] = df_stock['close'] - df_stock['open']
df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
df_stock['Std_dev']= df_stock['close'].rolling(5).std()
    
#prepare predicted
df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
#remove na after shift
df_stock = df_stock.dropna()
    
#define X
X = df_stock.iloc[:, 4:-1]
    
#define y
y = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)
    
#define split
split_percentage = 0.8
split = int(len(df_stock)*split_percentage)
    
#prepare train and test sets
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

#define scaler
sc = StandardScaler()
scaler = MinMaxScaler(feature_range=(0,1))
    
#scale-replace X_train and X_test
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#define and teach model
cls = SVC().fit(X_train, y_train)
    
#create metrics
accuracy_train_svm = accuracy_score(y_train, cls.predict(X_train))
accuracy_test_svm = accuracy_score(y_test, cls.predict(X_test))
    
#calculate returns
df_stock['Predicted_Signal'] = cls.predict(X)
df_stock['Market_Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
Cumulative_Market_Returns = df_stock[split:]['Market_Returns'].cumsum()*100

df_stock['Strategy_Returns'] = df_stock['Market_Returns'] * df_stock['Predicted_Signal'].shift(1)
Cumulative_Strategy_Returns = df_stock[split:]['Strategy_Returns'].cumsum()*100

Cumulative_SVM_Returns = Cumulative_Strategy_Returns

#calculate sharpe ratio
Std = Cumulative_Strategy_Returns.std()
Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
Sharpe_SVM = Sharpe.mean()
    
#return Sharpe_SVM

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Returns')

#plt.plot(Cumulative_KNN_Returns, color='m', label='KNN Returns')
#plt.plot(Cumulative_LR_Returns, color='c', label='LR Returns')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(cls.predict(X))

# %%
# KNN

#get stock
df_stock = extract_stock(stock_name)
    
#prepare variables
df_stock['H-L'] = df_stock['high'] - df_stock['low']
df_stock['O-C'] = df_stock['close'] - df_stock['open']
df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
df_stock['Std_dev']= df_stock['close'].rolling(5).std()
    
#prepare predicted
df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)
    
#remove na after shift
df_stock = df_stock.dropna()
    
#define X
X = df_stock.iloc[:, 4:-1]
    
#define y
y = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)
    
#define split
split_percentage = 0.8
split = int(split_percentage*len(df_stock))

#prepare train and test sets
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
#define and teach model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
    
#create metrics
accuracy_train_knn = accuracy_score(y_train, knn.predict(X_train))
accuracy_test_knn = accuracy_score(y_test, knn.predict(X_test))
    
#calculate returns
df_stock['Predicted_Signal'] = knn.predict(X)
df_stock['Market_Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
Cumulative_Market_Returns = df_stock[split:]['Market_Returns'].cumsum()*100

df_stock['Strategy_Returns'] = df_stock['Market_Returns'] * df_stock['Predicted_Signal'].shift(1)
Cumulative_Strategy_Returns = df_stock[split:]['Strategy_Returns'].cumsum()*100

Cumulative_KNN_Returns = Cumulative_Strategy_Returns

#calculate sharpe ratio
Std = Cumulative_Strategy_Returns.std()
Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
Sharpe_KNN = Sharpe.mean()
    
#return Sharpe_KNN

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Returns')

#plt.plot(Cumulative_KNN_Returns, color='m', label='KNN Returns')
#plt.plot(Cumulative_LR_Returns, color='c', label='LR Returns')
plt.grid()
plt.legend()
plt.show()

# %%
### LR

#get stock
df_stock = extract_stock(stock_name)
    
#prepare variables
df_stock['H-L'] = df_stock['high'] - df_stock['low']
df_stock['O-C'] = df_stock['close'] - df_stock['open']
df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
df_stock['Std_dev']= df_stock['close'].rolling(5).std()
df_stock = df_stock.dropna()
    
#prepare predicted
df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
#define X
X = df_stock.iloc[:, 4:-1]
    
#define y
y = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)

#define split
split_percentage = 0.8
split = int(split_percentage*len(df_stock))
    
#prepare train and test sets
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
#define and teach model
model = LogisticRegression()
model = model.fit(X_train,y_train)
    
#create metrics
accuracy_train_lr = accuracy_score(y_train, model.predict(X_train))
accuracy_test_lr = accuracy_score(y_test, model.predict(X_test))

pd.DataFrame(list(zip(X.columns, np.transpose(model.coef_))))
probability = model.predict_proba(X_test)
predicted = model.predict(X_test)
probability = model.predict_proba(X_test)
metrics.confusion_matrix(y_test, predicted)
metrics.classification_report(y_test, predicted)
model.score(X_test,y_test)
cross_val = cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=10)
cross_val.mean()
    
#calculate returns
df_stock['Predicted_Signal'] = model.predict(X)
df_stock['Market_Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
Cumulative_Market_Returns = df_stock[split:]['Market_Returns'].cumsum()*100

df_stock['Strategy_Returns'] = df_stock['Market_Returns'] * df_stock['Predicted_Signal'].shift(1)
Cumulative_Strategy_Returns = df_stock[split:]['Strategy_Returns'].cumsum()*100

Cumulative_LR_Returns = Cumulative_Strategy_Returns

#calculate sharpe ratio
Std = Cumulative_Strategy_Returns.std()
Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
Sharpe_LR = Sharpe.mean()
    
#return Sharpe_LR

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Returns')

#plt.plot(Cumulative_KNN_Returns, color='m', label='KNN Returns')
#plt.plot(Cumulative_LR_Returns, color='c', label='LR Returns')
plt.grid()
plt.legend()
plt.show()

# %%
df_stock = df.loc[df['Name'] == stock_name]

df_stock['date'] = pd.to_datetime(df_stock['date'])
df_stock['close'] = pd.to_numeric(df_stock['close'], downcast='float')

df_stock.set_index('date',inplace=True)  
df_stock.sort_index(inplace=True)  

df_stock.head()

# %%
Cumulative_ANN_Returns = Cumulative_ANN_Returns*(-1)

# %%
Cumulative_ANN_Returns = Cumulative_ANN_Returns*(-1)
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.plot(Cumulative_ANN_Returns, color='g', label='ANN Returns')

plt.plot(Cumulative_SVM_Returns, color='b', label='SVM Returns')
#plt.plot(Cumulative_KNN_Returns, color='m', label='KNN Returns')
#plt.plot(Cumulative_LR_Returns, color='c', label='LR Returns')
plt.grid()
plt.legend()
plt.show()

# %%
### OSWIECENIE
### PETLA UCZENIA SIECI PLOTOWANA CO EPOKE BEZ VERBOSE NA CUMULATIVE
### WPLYW NA ROZNE X'y

df_stock = df_stock.loc['2017-02-01':'2018-02-01']
plt.figure(figsize=(15,8))
plt.plot(df_stock['close'], color='g', label='Close')
plt.grid()
plt.legend()
plt.show()

# %%
print('accuracy_train_knn: ' + str(accuracy_train_knn))
print('accuracy_train_lr: ' + str(accuracy_train_lr))
print('accuracy_train_svm: ' + str(accuracy_train_svm))

print('accuracy_test_knn: ' + str(accuracy_test_knn))
print('accuracy_test_lr: ' + str(accuracy_test_lr))
print('accuracy_test_svm: ' + str(accuracy_test_svm))

# %%
##########################################################################################
################################### 0. ALL SCRIPTS END ###################################
##########################################################################################

# %%
###################################################################################################
################################### 1. START OF NEURAL NETWORKS ###################################
###################################################################################################

# %%
def ANN(df, stock_name):
    
    #get stock
    df_stock = extract_stock(stock_name)
    
    #prepare variables
    df_stock['H-L'] = df_stock['high'] - df_stock['low']
    df_stock['O-C'] = df_stock['close'] - df_stock['open']
    df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
    df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
    df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
    df_stock['Std_dev']= df_stock['close'].rolling(5).std()
    
    #prepare predicted
    df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
    #remove na after shift
    df_stock = df_stock.dropna()
    
    #define X
    X = df_stock.iloc[:, 4:-1]
    
    #define y
    y = df_stock.iloc[:, -1]
    
    #define split
    split_percentage = 0.8
    split = int(len(df_stock)*split_percentage)
    
    #prepare train and test sets
    X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
    #define scaler
    sc = StandardScaler()
    
    #scale-replace X_train and X_test
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    #define model
    classifier = Sequential()
    classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', input_dim = X.shape[1]))
    classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])
    
    #fit model
    history = classifier.fit(X_train, y_train, batch_size = 10, epochs = 150, verbose = 0, validation_data=(X_test, y_test))
    y_pred = classifier.predict(X_test)
    y_pred = (y_pred > 0.5)
    
    df_stock['y_pred'] = np.NaN
    df_stock.iloc[(len(df_stock) - len(y_pred)):,-1:] = y_pred
    trade_dataset = df_stock.dropna()
    
    #create metrics
    score = classifier.evaluate(X_test, y_test, verbose=1)
    accuracy_train_ANN = history.history['acc'][-1]
    accuracy_test_ANN = score[1]
    
    #calculate returns
    df_stock['Tomorrows Returns'] = 0.
    df_stock['Tomorrows Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
    df_stock['Tomorrows Returns'] = df_stock['Tomorrows Returns'].shift(-1)

    df_stock['Strategy Returns'] = 0.
    df_stock['Strategy Returns'] = np.where(df_stock['y_pred'] == True, df_stock['Tomorrows Returns'], - df_stock['Tomorrows Returns'])

    df_stock['Cumulative Market Returns'] = np.cumsum(df_stock['Tomorrows Returns'])
    df_stock['Cumulative Strategy Returns'] = np.cumsum(df_stock['Strategy Returns'])

    Cum_Strategy_Returns = df_stock['Cumulative Strategy Returns']
    Cumulative_Market_Returns = df_stock['Cumulative Market Returns']
    
    #calculate sharpe ratio
    Std = Cum_Strategy_Returns.std()
    Sharpe = (Cum_Strategy_Returns-Cumulative_Market_Returns)/Std
    Sharpe_ANN = Sharpe.mean()
    
    return (Sharpe_ANN, accuracy_train_ANN, accuracy_test_ANN, Cum_Strategy_Returns, Cumulative_Market_Returns)

# %%
def ANN2(df, stock_name):
    
    #get stock
    df_stock = extract_stock(stock_name)
    
    #prepare variables
    df_stock['H-L'] = df_stock['high'] - df_stock['low']
    df_stock['O-C'] = df_stock['close'] - df_stock['open']
    df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
    df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
    df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
    df_stock['Std_dev']= df_stock['close'].rolling(5).std()
    
    #prepare predicted
    df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
    #remove na after shift
    df_stock = df_stock.dropna()
    
    #define X
    X = df_stock.iloc[:, 4:-1]
    
    #define y
    y = df_stock.iloc[:, -1]
    
    #define split
    split_percentage = 0.8
    split = int(len(df_stock)*split_percentage)
    
    #prepare train and test sets
    X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
    #define scaler
    sc = StandardScaler()
    
    #scale-replace X_train and X_test
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    #define model
    classifier = Sequential()
    classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', input_dim = X.shape[1]))
    classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])
    
    #fit model
    history = classifier.fit(X_train, y_train, batch_size = 10, epochs = 150, verbose = 0, validation_data=(X_test, y_test))
    y_pred = classifier.predict(X)
    y_pred = (y_pred > 0.5)
    
    df_stock['y_pred'] = np.NaN
    df_stock.iloc[(len(df_stock) - len(y_pred)):,-1:] = y_pred
    ##trade_dataset = df_stock.dropna()
    
    #create metrics
    score = classifier.evaluate(X_test, y_test, verbose=1)
    accuracy_train_ANN = history.history['acc'][-1]
    accuracy_test_ANN = score[1]
    
    #calculate returns
    df_stock['Tomorrows Returns'] = 0.
    df_stock['Tomorrows Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
    df_stock['Tomorrows Returns'] = df_stock['Tomorrows Returns'].shift(-1)

    df_stock['Strategy Returns'] = 0.
    df_stock['Strategy Returns'] = np.where(df_stock['y_pred'] == True, df_stock['Tomorrows Returns'], - df_stock['Tomorrows Returns'])

    df_stock['Cumulative Market Returns'] = np.cumsum(df_stock['Tomorrows Returns'])
    df_stock['Cumulative Strategy Returns'] = np.cumsum(df_stock['Strategy Returns'])

    Cumulative_Strategy_Returns = df_stock['Cumulative Strategy Returns']*100
    Cumulative_Market_Returns = df_stock['Cumulative Market Returns']

    Cumulative_ANN_Returns = Cumulative_Strategy_Returns

    #calculate sharpe ratio
    Std = Cumulative_Strategy_Returns.std()
    Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
    Sharpe_ANN = Sharpe.mean()
    
    return (Sharpe_ANN, accuracy_train_ANN, accuracy_test_ANN, Cumulative_Strategy_Returns, Cumulative_Market_Returns)

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Returns')
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.legend()
plt.show()

# %%
#################################################################################################
################################### 1. END OF NEURAL NETWORKS ###################################
#################################################################################################

# %%
###################################################################################################
################################### 2. STARY OF SUPPORT VECTORS ###################################
###################################################################################################

# %%
def SVM(df, stock_name):
    
    #get stock
    df_stock = extract_stock(stock_name)
    
    #prepare variables
    df_stock['H-L'] = df_stock['high'] - df_stock['low']
    df_stock['O-C'] = df_stock['close'] - df_stock['open']
    df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
    df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
    df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
    df_stock['Std_dev']= df_stock['close'].rolling(5).std()
    
    #prepare predicted
    df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
    #remove na after shift
    df_stock = df_stock.dropna()
    
    #define X
    X = df_stock.iloc[:, 4:-1]
    
    #define y
    y = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)
    
    #define split
    split_percentage = 0.8
    split = int(len(df_stock)*split_percentage)
    
    #prepare train and test sets
    X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
    #define and teach model
    cls = SVC().fit(X_train, y_train)
    
    #create metrics
    accuracy_train_SVM = accuracy_score(y_train, cls.predict(X_train))
    accuracy_test_SVM = accuracy_score(y_test, cls.predict(X_test))
    
    #calculate returns
    df_stock['Predicted_Signal'] = cls.predict(X)
    df_stock['Market_Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
    Cumulative_Market_Returns = df_stock[split:]['Market_Returns'].cumsum()*100

    df_stock['Strategy_Returns'] = df_stock['Market_Returns'] * df_stock['Predicted_Signal'].shift(1)
    Cumulative_Strategy_Returns = df_stock[split:]['Strategy_Returns'].cumsum()*100
    
    #calculate sharpe ratio
    Std = Cumulative_Strategy_Returns.std()
    Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
    Sharpe_SVM = Sharpe.mean()
    
    return (Sharpe_SVM, accuracy_train_SVM, accuracy_test_SVM, Cumulative_Strategy_Returns, Cumulative_Market_Returns)

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Returns')
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.legend()
plt.show()

# %%
############################################################
################################### 2. END OF SUPPORT VECTORS ###################################
#################################################################################################

# %%
#######################################################################################
################################### 3. START OF KNN ###################################
#######################################################################################

# %%
def KNN(df, stock_name):
    
    #get stock
    df_stock = extract_stock(stock_name)
    
    #prepare variables
    df_stock['H-L'] = df_stock['high'] - df_stock['low']
    df_stock['O-C'] = df_stock['close'] - df_stock['open']
    df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
    df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
    df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
    df_stock['Std_dev']= df_stock['close'].rolling(5).std()
    
    #prepare predicted
    df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)
    
    #remove na after shift
    df_stock = df_stock.dropna()
    
    #define X
    X = df_stock.iloc[:, 4:-1]
    
    #define y
    y = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)
    
    #define split
    split_percentage = 0.8
    split = int(split_percentage*len(df_stock))

    #prepare train and test sets
    X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
    #define and teach model
    knn = KNeighborsClassifier(n_neighbors=10)
    knn.fit(X_train, y_train)
    
    #create metrics
    accuracy_train_KNN = accuracy_score(y_train, knn.predict(X_train))
    accuracy_test_KNN = accuracy_score(y_test, knn.predict(X_test))
    
    #calculate returns
    df_stock['Predicted_Signal'] = knn.predict(X)
    df_stock['Market_Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
    Cumulative_Market_Returns = df_stock[split:]['Market_Returns'].cumsum()*100

    df_stock['Strategy_Returns'] = df_stock['Market_Returns'] * df_stock['Predicted_Signal'].shift(1)
    Cumulative_Strategy_Returns = df_stock[split:]['Strategy_Returns'].cumsum()*100
    
    #calculate sharpe ratio
    Std = Cumulative_Strategy_Returns.std()
    Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
    Sharpe_KNN = Sharpe.mean()
    
    return (Sharpe_KNN, accuracy_train_KNN, accuracy_test_KNN, Cumulative_Strategy_Returns, Cumulative_Market_Returns)

# %%
plt.figure(figsize=(15,8))
plt.plot(Cumulative_Market_Returns, color='r', label='Market Returns')
plt.plot(Cumulative_Strategy_Returns, color='g', label='Strategy Retruns')
plt.legend()
plt.show()

# %%
#####################################################################################
################################### 3. END OF KNN ###################################
#####################################################################################

# %%
#######################################################################################################
################################### 4. START OF LOGISTIC REGRESSION ###################################
#######################################################################################################

# %%
def LR(df, stock_name):
    
    #get stock
    df_stock = extract_stock(stock_name)
    
    #prepare variables
    df_stock['H-L'] = df_stock['high'] - df_stock['low']
    df_stock['O-C'] = df_stock['close'] - df_stock['open']
    df_stock['3day MA'] = df_stock['close'].shift(1).rolling(window = 3).mean()
    df_stock['10day MA'] = df_stock['close'].shift(1).rolling(window = 10).mean()
    df_stock['30day MA'] = df_stock['close'].shift(1).rolling(window = 30).mean()
    df_stock['Std_dev']= df_stock['close'].rolling(5).std()
    df_stock = df_stock.dropna()
    
    #prepare predicted
    df_stock['Price_Rise'] = np.where(df_stock['close'].shift(-1) > df_stock['close'], 1, 0)
    
    #define X
    X = df_stock.iloc[:, 4:-1]
    
    #define y
    y = np.where(df_stock['close'].shift(-1) > df_stock['close'],1,-1)

    #define split
    split_percentage = 0.8
    split = int(split_percentage*len(df_stock))
    
    #prepare train and test sets
    X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
    
    #define and teach model
    model = LogisticRegression()
    model = model.fit(X_train,y_train)
    
    #create metrics
    accuracy_train_LR = accuracy_score(y_train, model.predict(X_train))
    accuracy_test_LR = accuracy_score(y_test, model.predict(X_test))
    
    #pd.DataFrame(list(zip(X.columns, np.transpose(model.coef_))))
    #probability = model.predict_proba(X_test)
    #predicted = model.predict(X_test)
    #probability = model.predict_proba(X_test)
    #metrics.confusion_matrix(y_test, predicted)
    #metrics.classification_report(y_test, predicted)
    #model.score(X_test,y_test)
    #cross_val = cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=10)
    #cross_val.mean()
    
    #calculate returns
    df_stock['Predicted_Signal'] = model.predict(X)
    df_stock['Market_Returns'] = np.log(df_stock['close']/df_stock['close'].shift(1))
    Cumulative_Market_Returns = df_stock[split:]['Market_Returns'].cumsum()*100

    df_stock['Strategy_Returns'] = df_stock['Market_Returns'] * df_stock['Predicted_Signal'].shift(1)
    Cumulative_Strategy_Returns = df_stock[split:]['Strategy_Returns'].cumsum()*100
    
    #calculate sharpe ratio
    Std = Cumulative_Strategy_Returns.std()
    Sharpe = (Cumulative_Strategy_Returns-Cumulative_Market_Returns)/Std
    Sharpe_LR = Sharpe.mean()
    
    return (Sharpe_LR, accuracy_train_LR, accuracy_test_LR, Cumulative_Strategy_Returns, Cumulative_Market_Returns)

# %%
plt.figure(figsize=(10,5))
plt.plot(Cumulative_Market_Returns, color='r',label = 'Market Returns')
plt.plot(Cumulative_Strategy_Returns, color='g', label = 'Strategy Returns')
plt.legend()
plt.show()

# %%
#####################################################################################################
################################### 4. END OF LOGISTIC REGRESSION ###################################
#####################################################################################################

# %%
print('Sharpe ANN ratio: %.2f' %Sharpe_ANN)
print('Sharpe SVM ratio: %.2f' %Sharpe_SVM.)
print('Sharpe KNN ratio: %.2f' %Sharpe_KNN)
print('Sharpe LR ratio: %.2f' %Sharpe_LR)

# %%
i = 1
for stock_name in stock_names:
    
    print('============= ' + str(i) + ' ===============')
    print('Analysis of ' + stock_name + ' started.')
    
    print('- ANN START -')
    sharpe_ann = ANN2(df, stock_name)
    print('Sharpe ANN ratio: %.2f' %sharpe_ann[0])
    print('- ANN FINISH -')
        
    print('- SVM START -')
    sharpe_svm = SVM(df, stock_name)
    print('Sharpe SVM ratio: %.2f' %sharpe_svm[0])
    print('- SVM FINISH -')
      
    print('- KNN START -')
    sharpe_knn = KNN(df, stock_name)
    print('Sharpe KNN ratio: %.2f' %sharpe_knn[0])
    print('- KNN FINISH -')
       
    print('- LR START -')
    sharpe_lr = LR(df, stock_name)
    print('Sharpe LR ratio: %.2f' %sharpe_lr[0])
    print('- LR FINISH -')
        
    print('Analysis of ' + stock_name + ' finished.')   
    print('Dumping results to dataframe')

    sharpes2 = pd.DataFrame(np.array([[stock_name, sharpe_ann[0], sharpe_svm[0], sharpe_knn[0], sharpe_lr[0], sharpe_ann[1], sharpe_ann[2], sharpe_svm[1], sharpe_svm[2], sharpe_knn[1], sharpe_knn[2], sharpe_lr[1], sharpe_lr[2]]]),
                            columns=['STOCK','ANN','SVM','KNN','LR','acc_ANN_train','acc_ANN_test','acc_SVM_train','acc_SVM_test','acc_KNN_train','acc_KNN_test','acc_LR_train','acc_LR_test']).append(sharpes, ignore_index=True)
    i=i+1

# %%
res

# %%
col_names = list(sharpes2)
for name in col_names:
    if name != 'STOCK':
        sharpes2[name] = sharpes2[name].astype(float)

sharpes2.round(3)

# %%
sharpes.to_csv('sharpes.csv')

# %%
stock_name = 'GE'

# %%
sharpes = pd.read_csv('sharpes.csv')
sharpes.drop(columns=['INDEX'])

# %%
plt.figure(figsize=(15,8))

plt.plot(sharpes.KNN)
plt.plot(sharpes.SVM)
plt.plot(sharpes.LR)
plt.plot(sharpes.ANN)

# %%
########## post-processing
### get 5 names with highest sharpe for each algorithm
top5_ann = sharpes.nlargest(5, 'ANN')
top5_svm = sharpes.nlargest(5, 'SVM')
top5_knn = sharpes.nlargest(5, 'KNN')
top5_lr = sharpes.nlargest(5, 'LR')

### get 5 names with lowest sharpe for each algorithm
bot5_ann = sharpes.nsmallest(5, 'ANN')
bot5_svm = sharpes.nsmallest(5, 'SVM')
bot5_knn = sharpes.nsmallest(5, 'KNN')
bot5_lr = sharpes.nsmallest(5, 'LR')

# %%
### compare graphs
stock_picks = top5_ann
for pick in stock_picks:
    df_stock = df.loc[df['Name'] == stock_name]
    df_stock['date'] = pd.to_datetime(df_stock['date'])
    df_stock['close'] = pd.to_numeric(df_stock['close'], downcast='float')
    df_stock.set_index('date',inplace=True)  
    df_stock.sort_index(inplace=True)  
    df_stock.head()
    
    algo = ANN(df, pick)[3]
    market = ANN(df, pick)[4]
    
    plt.figure(figsize=(15,8))
    plt.plot(market, color='r', label='Market Returns')
    plt.plot(algo, color='g', label='ANN Returns')
    plt.grid()
    plt.legend()
    plt.show()

# %%
df_stock = extract_stock(stock_name)

plt.figure(figsize=(15,8))
#df_stock = df_stock.loc['2017-02-01':'2018-02-01']
plt.plot(df_stock['close'], color='g', label='Close')
plt.grid()
plt.legend()
plt.show()

# %%
stock_picks = bot5_svm
for pick in stock_picks.STOCK.values:
    
    df_stock = df.loc[df['Name'] == pick]
    df_stock['date'] = pd.to_datetime(df_stock['date'])
    df_stock['close'] = pd.to_numeric(df_stock['close'], downcast='float')
    
    df_stock.set_index('date',inplace=True)  
    df_stock.sort_index(inplace=True)  
    df_stock = df_stock.loc['2017-02-17':]

    res = SVM(df, pick)
    
    algo = res[3]
    market = res[4]
    close = df_stock['close']
    
    
    fig, ax1 = plt.subplots()
    color = 'tab:red'
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Returns in %', color='k')
    ax1.plot(algo, color=color)
    ax1.tick_params(axis='y', labelcolor='k')
    
    color = 'tab:blue'
    ax1.plot(market, color=color)
    ax1.tick_params(axis='y', labelcolor='k')
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:green'
    ax2.set_ylabel('Closing Price in USD', color='k')  # we already handled the x-label with ax1
    ax2.plot(df_stock['close'], color=color)
    ax2.tick_params(axis='y', labelcolor='k')
    ax2.grid()
    fig.tight_layout()# otherwise the right y-label is slightly clipped
    fig.legend(loc=1)
    fig.set_figwidth(15)
    fig.set_figheight(8)

    plt.show()
